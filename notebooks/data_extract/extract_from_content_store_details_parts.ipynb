# %%
import os
import yaml
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import pymongo
import warnings
from bs4 import BeautifulSoup
import datetime
from lxml import etree
from itertools import chain
from lxml import html
warnings.filterwarnings('ignore', category=UserWarning, module='bs4')

# %%
DATA_DIR = os.getenv("DATA_DIR")
CONFIG = os.getenv("CONFIG")
blacklist_path = os.path.join(CONFIG, 'document_types_excluded_from_the_topic_taxonomy.yml')

# %%
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")

content_store_db = mongo_client["content_store"]
content_store_collection = content_store_db["content_items"]

# %%
def get_excluded_document_types():
    with open(blacklist_path, 'r') as f:
        return yaml.safe_load(f)['document_types']

# %%
BLACKLIST_DOCUMENT_TYPES = get_excluded_document_types()
BLACKLIST_DOCUMENT_TYPES[0:5]
# Out:
# ['about',
#  'about_our_services',
#  'access_and_opening',
#  'business_support_finder',
#  'coming_soon']

# %%
TEXT_PROJECTION = {
    "locale":1,
    "details.parts": 1,
    "title":1,
    "description":1,
    "document_type": 1,
    "content_id": 1}

FILTER_BASIC = {"$and": [
    {"document_type": {"$nin": BLACKLIST_DOCUMENT_TYPES}},
    {"phase": "live"}]}

# %%
content_items = content_store_collection.find(FILTER_BASIC, TEXT_PROJECTION)
rowlist = []
for i,item in enumerate(content_items):
    if len(item['details']) > 0:
        rowlist.append(item)
df = pd.DataFrame(rowlist)
df
# Out:
#                                                    _id  \
# 0                                   /1619-bursary-fund
# 1                            /additional-state-pension
# 2                                 /adi-standards-check
# 3                     /administrative-appeals-tribunal
# 4                                     /adi-part-2-test
# 5                       /access-to-elected-office-fund
# 6                                     /adi-part-3-test
# 7                                      /access-to-work
# 8                    /ad-dalu-eich-benthyciad-myfyrwyr
# 9                                     /adi-part-1-test
# 10                               /attendance-allowance
# 11                            /au-pairs-employment-law
# 12                         /bail-immigration-detainees
# 13                                         /bankruptcy
# 14                      /become-a-fleet-driver-trainer
# 15                              /become-an-mot-station
# 16                               /become-an-mot-tester
# 17                           /become-childminder-nanny
# 18                                      /become-deputy
# 19   /become-direct-access-scheme-motorcycle-instru...
# 20     /become-dvsa-assessed-cbt-motorcycle-instructor
# 21                            /become-lorry-bus-driver
# 22                                  /become-magistrate
# 23                    /becoming-a-speed-limiter-centre
# 24                     /being-a-goods-vehicle-operator
# 25                                /being-made-bankrupt
# 26     /being-taken-to-employment-tribunal-by-employee
# 27                                        /benefit-cap
# 28                               /benefit-overpayments
# 29                                /benefits-and-prison
# ..                                                 ...
# 803        /voluntary-national-insurance-contributions
# 804            /weights-measures-and-packaging-the-law
# 805              /what-you-must-do-as-a-cis-contractor
# 806           /what-you-must-do-as-a-cis-subcontractor
# 807                         /wills-probate-inheritance
# 808         /turkish-worker-business-person-settlement
# 809                                       /twe-ar-lein
# 810                          /types-of-prison-sentence
# 811                     /uk-visa-sponsorship-employers
# 812                   /unclaimed-estates-bona-vacantia
# 813                 /understand-how-your-council-works
# 814       /workplace-fire-safety-your-responsibilities
# 815                             /vat-building-new-home
# 816                                     /vat-charities
# 817                                /vat-margin-schemes
# 818                                  /vehicle-approval
# 819                                 /vehicle-insurance
# 820                           /vehicle-tax-rate-tables
# 821  /visas-and-immigration-service-and-support-cen...
# 822                         /volunteer-as-a-coastguard
# 823             /wind-up-a-company-that-owes-you-money
# 824                         /working-with-trade-unions
# 825                           /young-people-in-custody
# 826    /your-employment-contract-how-it-can-be-changed
# 827                          /your-property-boundaries
# 828                           /your-rights-after-crime
# 829                              /your-rights-bailiffs
# 830         /your-rights-if-your-employer-is-insolvent
# 831                 /youth-crime-prevention-programmes
# 832                                 /yswiriant-gwladol
#
#                                content_id  \
# 0    f4b96a38-5247-4afd-b554-8a258a0e8c93
# 1    e78637eb-3be4-408c-9f9c-d2336635c0ca
# 2    2574c147-77ee-4c4d-b149-546d508cb65d
# 3    879787a9-1201-42d9-8a96-004e0483b38b
# 4    d4ec198a-6624-4e1c-8dd9-76e24a53b4e2
# 5    e12e3c54-b544-4d94-ba1f-9846144374d2
# 6    91225b0d-0e5d-4118-8c9c-6465fc9a1775
# 7    d27a7826-745c-4a54-b2e9-00a379da8671
# 8    19547168-aa4d-40bc-8af9-67ff9c041b42
# 9    f2533b63-0341-4b9a-b37e-a88276b4783e
# 10   916b042a-ee5c-420b-8481-17c74e7bb456
# 11   61289398-23be-4fad-b7c0-0da35e512148
# 12   fb795e5e-cab1-4bb6-90be-ff33010d82e7
# 13   64aadc14-9bca-40d9-abb6-4f21f9792a05
# 14   07241c77-ce43-45a2-91a2-d348690856f3
# 15   a898a5cf-0cce-4a00-8d75-f1c9fc780992
# 16   e8a3973a-979d-4690-8603-1bd453c4319c
# 17   c0e8700b-24ad-4c7a-86d3-9ccc7a8ec11f
# 18   a918d7e7-129b-45f6-9887-831a92833936
# 19   ca9a2861-f3eb-451e-ad51-759d48597b6d
# 20   173cdc59-66a5-4ed6-ad3f-fa175576f347
# 21   ade4791d-a7fa-451b-afd1-6d0ad00ee630
# 22   62c9ef3d-dc9f-4746-bb20-0a118fab897e
# 23   301ba4e4-ae12-4d18-9198-cb82f1383568
# 24   8b27d85a-e16b-4269-8ca6-56b22a180f4e
# 25   bbc66187-0901-499b-8ecb-8c3084d43b9f
# 26   0d12a2da-7c52-4cd9-82ef-0cca0b51b880
# 27   4466597b-9531-4c2e-af89-2380f7ec5660
# 28   7e2083a7-0e11-48bd-8d07-9b7bd6aaf966
# 29   e7c4687e-4b1c-40fc-b161-36d32cb6e305
# ..                                    ...
# 803  0693ad2b-8185-4e5a-b817-377b0c23a228
# 804  1fedcfc0-b0df-4f10-9f9a-bad37048851f
# 805  8e49dcfd-92db-4f5e-8fb2-a600324a9429
# 806  43fc2b1d-6751-41a3-852d-c081711a75f4
# 807  c25b48e9-bdae-4870-845d-5a67c1189fe1
# 808  870d4b1a-063b-456e-841c-78d32d8d5be3
# 809  aa9433b7-6b86-4729-a1ec-5c02dc188100
# 810  642096d9-e9e5-43f7-b545-2e34e82d8fda
# 811  84914675-3c9f-462b-89f7-5e54257c63f4
# 812  f9240f4a-d34c-4a79-a570-43fee819ce35
# 813  df61f873-f42f-4fb9-8e8e-17fa6a583270
# 814  74e934ef-48e8-4b3f-a87c-1cd05e7958d9
# 815  7757ba54-161a-479a-96a2-a50420929f1a
# 816  ffe03767-3130-4903-8579-269edf93377b
# 817  90d86a20-80f0-4259-9fcf-5dbcd1f82123
# 818  195d2a02-fabf-47b3-a01c-1745d927dcdd
# 819  5305660e-bfba-4c41-b170-96dcfcf88099
# 820  db364fa7-96c5-42c2-a3db-ce06d4a7c97e
# 821  39726999-31c8-4b0e-a796-ef06f3f85818
# 822  18a997f1-38b7-4861-971a-db010b3bd6e8
# 823  64135ddf-7e6d-4d64-a917-77199bfeb34d
# 824  088bed7b-0b5a-4da7-9ee7-2e2a87acda05
# 825  781ad694-1e81-4a6a-bcb9-be426942e726
# 826  2edee9ab-76a1-44de-8c92-07aaf5469d18
# 827  6a948ea8-3923-408b-9a9a-716c1552a0c8
# 828  a443f6bd-e005-4003-986f-517e37e63b56
# 829  5179386b-b70f-4cf2-a5a7-84515fb726ae
# 830  de09348e-cb0c-4d58-96f3-4ff2156a236e
# 831  59106f04-26f9-43d6-8950-b2cfcd0fd7e6
# 832  eabe3d14-0e3c-4186-bf48-6c6ed11c58a7
#
#                                            description  \
# 0    {'value': 'Bursaries of up to £1,200 for stude...
# 1    {'value': 'Additional State Pension, also know...
# 2    {'value': 'When you have to take an ADI standa...
# 3    {'value': 'You can appeal to the Upper Tribuna...
# 4    {'value': 'Taking the approved driving instruc...
# 5    {'value': 'The Access to Elected Office Fund h...
# 6    {'value': 'Taking the approved driving instruc...
# 7    {'value': 'Get help at work, including an Acce...
# 8    {'value': 'Pryd y byddwch yn dechrau ad-dalu e...
# 9    {'value': 'Taking the approved driving instruc...
# 10   {'value': 'Attendance Allowance helps pay for ...
# 11   {'value': 'The employment status of au pairs, ...
# 12   {'value': 'How immigrants held on immigration ...
# 13   {'value': 'How to apply for bankruptcy: how lo...
# 14   {'value': 'Join the voluntary register of flee...
# 15   {'value': 'What you need to do to set up your ...
# 16   {'value': 'Becoming an MOT tester - eligibilit...
# 17   {'value': 'How to register as a childminder or...
# 18   {'value': 'How to become and act as a Court of...
# 19   {'value': 'How to become a direct access schem...
# 20   {'value': 'Become a Driver and Vehicle Standar...
# 21   {'value': 'How to become a qualified lorry or ...
# 22   {'value': 'How to volunteer as a magistrate, w...
# 23   {'value': 'How to become an approved speed lim...
# 24   {'value': 'Information about becoming a goods ...
# 25   {'value': 'What to do if you've been made bank...
# 26   {'value': 'What to do if you're an employer wh...
# 27   {'value': 'There is a limit on the total amoun...
# 28   {'value': 'Benefit overpayments - how they hap...
# 29   {'value': 'What happens to benefits if you or ...
# ..                                                 ...
# 803  {'value': 'National Insurance contributions yo...
# 804  {'value': 'Weights and measures - find out the...
# 805  {'value': 'What you have to do under the Const...
# 806  {'value': 'What subcontractors in the building...
# 807  {'value': 'Sorting out a deceased person's aff...
# 808  {'value': 'You can apply for settlement (known...
# 809  {'value': 'Cofrestrwch a defnyddiwch wasanaeth...
# 810  {'value': 'The range of prison sentences a cou...
# 811  {'value': 'UK visa sponsorship information for...
# 812  {'value': 'If someone dies without a will or k...
# 813  {'value': 'How local councils work in England ...
# 814  {'value': 'Fire safety in business and non-dom...
# 815  {'value': 'VAT refunds on building new homes a...
# 816  {'value': 'VAT relief available to charities -...
# 817  {'value': 'How to use VAT margin schemes - rec...
# 818  {'value': 'Type approval, individual (IVA), mo...
# 819  {'value': 'Rules on what motor insurance you n...
# 820  {'value': 'Tables showing the rates for vehicl...
# 821  {'value': 'What happens at a Service and Suppo...
# 822  {'value': 'Volunteer for the Coastguard Rescue...
# 823  {'value': 'How to issue a winding up petition ...
# 824  {'value': 'Working effectively with trade unio...
# 825  {'value': 'Why young people are sent to custod...
# 826  {'value': 'How employment contracts can be cha...
# 827  {'value': 'About your property boundaries, wor...
# 828  {'value': 'If you've been the victim of a crim...
# 829  {'value': 'Your rights when bailiffs visit you...
# 830  {'value': 'If your employer is 'insolvent' thi...
# 831  {'value': 'Youth crime prevention programmes -...
# 832  {'value': 'Rydych yn talu cyfraniadau yswirian...
#
#                                                details document_type locale  \
# 0    {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 1    {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 2    {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 3    {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 4    {'parts': [{'title': 'Booking your test', 'slu...         guide     en
# 5    {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 6    {'parts': [{'title': 'Booking your test', 'slu...         guide     en
# 7    {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 8    {'parts': [{'title': 'Trosolwg', 'slug': 'tros...         guide     cy
# 9    {'parts': [{'title': 'Booking your test', 'slu...         guide     en
# 10   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 11   {'parts': [{'title': 'Overview', 'slug': 'nann...         guide     en
# 12   {'parts': [{'title': 'Before you apply', 'slug...         guide     en
# 13   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 14   {'parts': [{'title': 'How to qualify as a flee...         guide     en
# 15   {'parts': [{'title': 'What you need to set up ...         guide     en
# 16   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 17   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 18   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 19   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 20   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 21   {'parts': [{'title': 'Getting qualified', 'slu...         guide     en
# 22   {'parts': [{'title': 'What magistrates do', 's...         guide     en
# 23   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 24   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 25   {'parts': [{'title': 'When you can be made ban...         guide     en
# 26   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 27   {'parts': [{'title': 'Benefits affected by the...         guide     en
# 28   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 29   {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# ..                                                 ...           ...    ...
# 803  {'parts': [{'title': 'Gaps in your National In...         guide     en
# 804  {'parts': [{'title': 'Units of measurement', '...         guide     en
# 805  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 806  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 807  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 808  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 809  {'parts': [{'title': 'Defnyddio TWE Ar-lein', ...         guide     cy
# 810  {'parts': [{'title': 'Concurrent and consecuti...         guide     en
# 811  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 812  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 813  {'parts': [{'title': 'Types of council', 'slug...         guide     en
# 814  {'parts': [{'title': 'Who's responsible', 'slu...         guide     en
# 815  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 816  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 817  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 818  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 819  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 820  {'parts': [{'title': 'Cars and some motorhomes...         guide     en
# 821  {'parts': [{'title': 'Appointments', 'slug': '...         guide     en
# 822  {'parts': [{'title': 'What the Coastguard Resc...         guide     en
# 823  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 824  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 825  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 826  {'parts': [{'title': 'Getting agreement', 'slu...         guide     en
# 827  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 828  {'parts': [{'title': 'Your rights', 'slug': 'y...         guide     en
# 829  {'parts': [{'title': 'What you can do when a b...         guide     en
# 830  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 831  {'parts': [{'title': 'Overview', 'slug': 'over...         guide     en
# 832  {'parts': [{'title': 'Trosolwg', 'slug': 'tros...         guide     cy
#
#                                                  title
# 0                                16 to 19 Bursary Fund
# 1                             Additional State Pension
# 2    Approved driving instructor (ADI) standards check
# 3    Appeal to the Upper Tribunal (Administrative A...
# 4        Approved driving instructor (ADI) part 2 test
# 5                        Access to Elected Office Fund
# 6        Approved driving instructor (ADI) part 3 test
# 7    Get help at work if you’re disabled or have a ...
# 8                     Ad-dalu eich benthyciad myfyrwyr
# 9        Approved driving instructor (ADI) part 1 test
# 10                                Attendance Allowance
# 11              Employing someone to work in your home
# 12                          Immigration detention bail
# 13                         Applying to become bankrupt
# 14                       Become a fleet driver trainer
# 15                          Set up an MOT test station
# 16                                Become an MOT tester
# 17             Become a childminder or nanny (England)
# 18   Deputies: make decisions for someone who lacks...
# 19   Become a direct access scheme (DAS) motorcycle...
# 20    Become a DVSA assessed CBT motorcycle instructor
# 21              Become a qualified lorry or bus driver
# 22                                 Become a magistrate
# 23                     Becoming a speed limiter centre
# 24                      Being a goods vehicle operator
# 25                                 Being made bankrupt
# 26               Being taken to an employment tribunal
# 27                                         Benefit cap
# 28                                Benefit overpayments
# 29                                 Benefits and prison
# ..                                                 ...
# 803                       Voluntary National Insurance
# 804                      Weights and measures: the law
# 805  What you must do as a Construction Industry Sc...
# 806  What you must do as a Construction Industry Sc...
# 807                     Wills, probate and inheritance
# 808  Apply for settlement if you're a Turkish Worke...
# 809                            TWE Ar-lein i Gyflogwyr
# 810                          Types of prison sentences
# 811                  UK visa sponsorship for employers
# 812                 Claim or refer an unclaimed estate
# 813                  Understand how your council works
# 814                       Fire safety in the workplace
# 815                        Building a new home and VAT
# 816                                  VAT for charities
# 817                                 VAT margin schemes
# 818                                   Vehicle approval
# 819                                  Vehicle insurance
# 820                                  Vehicle tax rates
# 821  Visas and immigration Service and Support Centres
# 822                          Volunteer as a coastguard
# 823              Wind up a company that owes you money
# 824               Working with trade unions: employers
# 825                            Young people in custody
# 826                    Changing an employment contract
# 827                           Your property boundaries
# 828                         After a crime: your rights
# 829           Bailiff powers when they visit your home
# 830          Your rights if your employer is insolvent
# 831                  Youth crime prevention programmes
# 832                                  Yswiriant Gwladol
#
# [833 rows x 7 columns]

# %%
for entry in df[df.details.str.len()>0].details.iloc[0]['parts']:
    
    for subentry in entry['body']:
        print(subentry['content'])
        print("####")
# Out:
# You could get a bursary to help with education-related costs if you’re aged 16 to 19 and:
#
# + studying at a publicly funded school or college in England - not a university
# + on a training course, including unpaid work experience
#
# A publicly funded school is one that does not charge you for attending it.
#
# ^There's a different [scheme in Wales, Scotland and Northern Ireland](/education-maintenance-allowance-ema).^
#
# ##If you're 19 and over
#
# You could also get a bursary if you either:
#
# * are continuing on a course you started aged 16 to 18 (known as being a ’19+ continuer’)
# * have an [Education, Health and Care Plan (EHCP)](/children-with-special-educational-needs/extra-SEN-help)
#
# ##What a bursary is for
# A bursary is money that you, or your education or training provider, can use to pay for things like:
#
# + clothing, books and other equipment for your course
# + transport and lunch on days you study or train
#
#
#
#
#
# ####
# <p>You could get a bursary to help with education-related costs if you’re aged 16 to 19 and:</p>
#
# <ul>
#   <li>studying at a publicly funded school or college in England - not a university</li>
#   <li>on a training course, including unpaid work experience</li>
# </ul>
#
# <p>A publicly funded school is one that does not charge you for attending it.</p>
#
# <div role="note" aria-label="Information" class="application-notice info-notice">
# <p>There’s a different <a href="/education-maintenance-allowance-ema">scheme in Wales, Scotland and Northern Ireland</a>.</p>
# </div>
#
# <h2 id="if-youre-19-and-over">If you’re 19 and over</h2>
#
# <p>You could also get a bursary if you either:</p>
#
# <ul>
#   <li>are continuing on a course you started aged 16 to 18 (known as being a ’19+ continuer’)</li>
#   <li>have an <a href="/children-with-special-educational-needs/extra-SEN-help">Education, Health and Care Plan (EHCP)</a>
# </li>
# </ul>
#
# <h2 id="what-a-bursary-is-for">What a bursary is for</h2>
# <p>A bursary is money that you, or your education or training provider, can use to pay for things like:</p>
#
# <ul>
#   <li>clothing, books and other equipment for your course</li>
#   <li>transport and lunch on days you study or train</li>
# </ul>
#
#
# ####
# There are 2 types of 16 to 19 bursary.
#
# ##Bursary for students in vulnerable groups
# You could get a bursary worth up to £1,200, depending on [your circumstances and benefits](/1619-bursary-fund/eligibility).
#
#
# ##Discretionary bursary
# You could get a discretionary bursary if you need financial help but do not qualify for a bursary for students in vulnerable groups. Your education or training provider decides how much you get and what it's used for.
#
# ^If you're over 19, you'll only be eligible for a discretionary bursary.
#
# ##How your bursary is paid
# Your provider will decide how you get your bursary. You might be:
#
# + paid in full or in instalments
# + paid in cash, by cheque or through a bank account
# + given things like a travel pass, free meals or books instead of money
#
# Some providers also offer one-off payments to cover study trips or travel for university interviews.
#
# %Your provider could stop payments if you break their rules, for example about attendance or how your bursary is used.%
#
#
# ####
# <p>There are 2 types of 16 to 19 bursary.</p>
#
# <h2 id="bursary-for-students-in-vulnerable-groups">Bursary for students in vulnerable groups</h2>
# <p>You could get a bursary worth up to £1,200, depending on <a href="/1619-bursary-fund/eligibility">your circumstances and benefits</a>.</p>
#
# <h2 id="discretionary-bursary">Discretionary bursary</h2>
# <p>You could get a discretionary bursary if you need financial help but do not qualify for a bursary for students in vulnerable groups. Your education or training provider decides how much you get and what it’s used for.</p>
#
# <div role="note" aria-label="Information" class="application-notice info-notice">
# <p>If you’re over 19, you’ll only be eligible for a discretionary bursary.</p>
# </div>
#
# <h2 id="how-your-bursary-is-paid">How your bursary is paid</h2>
# <p>Your provider will decide how you get your bursary. You might be:</p>
#
# <ul>
#   <li>paid in full or in instalments</li>
#   <li>paid in cash, by cheque or through a bank account</li>
#   <li>given things like a travel pass, free meals or books instead of money</li>
# </ul>
#
# <p>Some providers also offer one-off payments to cover study trips or travel for university interviews.</p>
#
# <div role="note" aria-label="Help" class="application-notice help-notice">
# <p>Your provider could stop payments if you break their rules, for example about attendance or how your bursary is used.</p>
# </div>
#
#
# ####
# You must:
#
# + be at least 16 and under 19 on 31 August 2019
# + study at a publicly funded school or college, or be on an unpaid training course
# + meet the residency requirements - your school or college can check this
#
# ##Bursary for students in vulnerable groups
#
# You could get up to £1,200 if at least one of the following applies:
#
# + you're in or recently left local authority care
# + you get Income Support or Universal Credit because you're financially supporting yourself
# + you get Disability Living Allowance (DLA) in your name and either Employment and Support Allowance (ESA) or Universal Credit
# + you get Personal Independence Payment (PIP) in your name and either ESA or Universal Credit
#
# You may get the full amount if you have expenses and study full-time on a course of at least 30 weeks.
#
# You’ll usually get less than the full amount, or no bursary, if one of the following apply:
#
# + your course is shorter than 30 weeks
# + you study part time
# + you have few expenses
#
# You’ll be told what evidence you need, for example benefit letters.
#
# ##Discretionary bursary
#
# Your school or college will have their own criteria for discretionary bursaries. They’ll look at your individual circumstances - this usually includes your family income.
#
# Ask student services about their criteria and any evidence you'll need.
#
# You can apply to a discretionary bursary if you're over 19 and either:
#
# * continuing on a course you started aged 16 to 18 (known as being a ‘19+ continuer’)
# * have an [Education, Health and Care Plan (EHCP)](/children-with-special-educational-needs/extra-SEN-help)
#
# *[ESA]: Employment and Support Allowance
# *[DLA]: Disability Living Allowance
# *[PIP]: Personal Independence Payment
#
# ####
# <p>You must:</p>
#
# <ul>
#   <li>be at least 16 and under 19 on 31 August 2019</li>
#   <li>study at a publicly funded school or college, or be on an unpaid training course</li>
#   <li>meet the residency requirements - your school or college can check this</li>
# </ul>
#
# <h2 id="bursary-for-students-in-vulnerable-groups">Bursary for students in vulnerable groups</h2>
#
# <p>You could get up to £1,200 if at least one of the following applies:</p>
#
# <ul>
#   <li>you’re in or recently left local authority care</li>
#   <li>you get Income Support or Universal Credit because you’re financially supporting yourself</li>
#   <li>you get Disability Living Allowance (<abbr title="Disability Living Allowance">DLA</abbr>) in your name and either Employment and Support Allowance (<abbr title="Employment and Support Allowance">ESA</abbr>) or Universal Credit</li>
#   <li>you get Personal Independence Payment (<abbr title="Personal Independence Payment">PIP</abbr>) in your name and either <abbr title="Employment and Support Allowance">ESA</abbr> or Universal Credit</li>
# </ul>
#
# <p>You may get the full amount if you have expenses and study full-time on a course of at least 30 weeks.</p>
#
# <p>You’ll usually get less than the full amount, or no bursary, if one of the following apply:</p>
#
# <ul>
#   <li>your course is shorter than 30 weeks</li>
#   <li>you study part time</li>
#   <li>you have few expenses</li>
# </ul>
#
# <p>You’ll be told what evidence you need, for example benefit letters.</p>
#
# <h2 id="discretionary-bursary">Discretionary bursary</h2>
#
# <p>Your school or college will have their own criteria for discretionary bursaries. They’ll look at your individual circumstances - this usually includes your family income.</p>
#
# <p>Ask student services about their criteria and any evidence you’ll need.</p>
#
# <p>You can apply to a discretionary bursary if you’re over 19 and either:</p>
#
# <ul>
#   <li>continuing on a course you started aged 16 to 18 (known as being a ‘19+ continuer’)</li>
#   <li>have an <a href="/children-with-special-educational-needs/extra-SEN-help">Education, Health and Care Plan (EHCP)</a>
# </li>
# </ul>
#
#
# ####
# Apply to your school, college or training provider. Ask student services or your tutor to explain what you need to do.
#
# ##When to apply
# Apply once you know where you’ll study or train, so you'll get your bursary as soon as possible.
#
# You might need to reapply for a bursary for each year of your course. Check with your provider.
#
#
# ####
# <p>Apply to your school, college or training provider. Ask student services or your tutor to explain what you need to do.</p>
#
# <h2 id="when-to-apply">When to apply</h2>
# <p>Apply once you know where you’ll study or train, so you’ll get your bursary as soon as possible.</p>
#
# <p>You might need to reapply for a bursary for each year of your course. Check with your provider.</p>
#
#
# ####
# Your tutor or student services can help you decide if you’re eligible for a bursary and explain how to apply.
#
# ^Read more [detailed guidance](https://www.gov.uk/guidance/advice-for-young-people-16-to-19-bursary-fund-guide) on the 16 to 19 Bursary Fund.^
#
# [Contact the Education and Skills Funding Agency (ESFA)](https://form.education.gov.uk/en/AchieveForms/?form_uri=sandbox-publish://AF-Process-f9f4f5a1-936f-448b-bbeb-9dcdd595f468/AF-Stage-8aa41278-3cdd-45a3-ad87-80cbffb8b992/definition.json&redirectlink=%2Fen&cancelRedirectLink=%2Fen&consentMessage=yes) if your tutor or student services cannot answer your question.
#
#
# ##You think a decision is unfair
# Speak to student services if you’re unhappy with a decision. Follow their complaints process if you cannot resolve the problem.
#
# ##Emergencies and hardship
# You might be able to get more support if your circumstances change or you have an emergency. Your provider might also have a separate hardship fund. Speak to student services if you need extra help.
#
# *[ESFA]: Education and Skills Funding Agency
# ####
# <p>Your tutor or student services can help you decide if you’re eligible for a bursary and explain how to apply.</p>
#
# <div role="note" aria-label="Information" class="application-notice info-notice">
# <p>Read more <a href="https://www.gov.uk/guidance/advice-for-young-people-16-to-19-bursary-fund-guide">detailed guidance</a> on the 16 to 19 Bursary Fund.</p>
# </div>
#
# <p><a rel="external" href="https://form.education.gov.uk/en/AchieveForms/?form_uri=sandbox-publish://AF-Process-f9f4f5a1-936f-448b-bbeb-9dcdd595f468/AF-Stage-8aa41278-3cdd-45a3-ad87-80cbffb8b992/definition.json&amp;redirectlink=%2Fen&amp;cancelRedirectLink=%2Fen&amp;consentMessage=yes">Contact the Education and Skills Funding Agency (<abbr title="Education and Skills Funding Agency">ESFA</abbr>)</a> if your tutor or student services cannot answer your question.</p>
#
# <h2 id="you-think-a-decision-is-unfair">You think a decision is unfair</h2>
# <p>Speak to student services if you’re unhappy with a decision. Follow their complaints process if you cannot resolve the problem.</p>
#
# <h2 id="emergencies-and-hardship">Emergencies and hardship</h2>
# <p>You might be able to get more support if your circumstances change or you have an emergency. Your provider might also have a separate hardship fund. Speak to student services if you need extra help.</p>
#
#
# ####

# %%
df.shape
# Out:
# (833, 7)

# %%
# df['orgs_id'] = df['expanded_links'].map(extract_org_id)
# df

# %%
def is_html(text):
    """
    Checks whether text is html or not
    :param text: string
    :return: bool
    """
    try:
        return bool(BeautifulSoup(text, "html.parser").find())
    # might be fine to except all exceptions here, as it's a low-level function
    except Exception:
        return False

def extract_text_from_content_details(data):
    """
    Recurses through lists and dicts to find html and then extract links BE VERY CAREFUL AND PASS IN LINKS, otherwise old links may persist in the list
    :param data: This function can accept a nested list or dict, or string
    :return:
    """
    if type(data) == list:
        return "".join(list(chain.from_iterable([
            extract_text_from_content_details(item)
            for item in data
        ])))
    elif type(data) == dict:
        return extract_text_from_content_details(list(data.values()))
    elif is_html(data):
        return extract_text(data)
    else:
        return ""

def extract_text(body):
    """
    Extract text from html body
    :param body: <str> containing html.
    """
    # TODO: Tidy this up!
    r = None
    # body != "\n" and
    if body and body != "\n" and not body.isspace():
        try:
            # print("this is", body)
            tree = etree.HTML(body)
            r = tree.xpath('//text()')
            r = ' '.join(r)
            r = r.strip().replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
            r = r.replace('\n', ' ').replace(',', ' ')
            # r = r.lower()
            r = ' '.join(r.split())
        except ValueError:
            print("exception @ extract:", type(body), body)
    if not r:
        r = ' '
    return r

# %%
def get_page_data(mongodb_collection):
    """
    Queries a MongoDB collection, get specific fields from details using TEXT_PROJECTION, converts this cursor to a DataFrame, with all details fields in one list column
    :param mongodb_collection:
    :return: pandas DataFrame with: _id (base_path), content_id, and all_details list column
    """
    content_items = mongodb_collection.find(FILTER_BASIC, TEXT_PROJECTION)
    row_list = []
    
    for i,item in enumerate(content_items):

        row_list.append(item)

        if i % 20000==0:
            print(datetime.datetime.now().strftime("%H:%M:%S"),":",i)

    return row_list

def df_wrapper(mongodb_collection):
    data_list = get_page_data(mongodb_collection)
    df = pd.DataFrame(data_list)
    df.rename(columns={'_id':'base_path','details':'text'}, inplace=True)
    return df[['base_path', 'content_id', 'title', 'description', 
               'document_type', 'orgs_id', 'orgs_title','sbs_details', 'pages_part_of_step_nav',
               'text', 'taxons', 'locale']]

# %%
df = df_wrapper(content_store_collection)

# %%
df[0:10]

# %%
df.to_csv(os.path.join(DATA_DIR, "preprocessed_content_store.csv.gz"), 
          index=False, 
          compression="gzip")

# %%
df.shape
