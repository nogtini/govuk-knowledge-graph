# %%
import os 
import pandas as pd 
import json
import urllib.request
from ast import literal_eval
from bs4 import BeautifulSoup
from collections import Counter

# %%
DATA_DIR = os.getenv("DATA_DIR")
curr_app_data = os.path.join(DATA_DIR, "current_appointment_edgelist.csv")
prev_app_data = os.path.join(DATA_DIR, "previous_appointment_edgelist.csv")

df1 = pd.read_csv(curr_app_data)
df1['app_type'] = 'current'
df2 = pd.read_csv(prev_app_data)
df2['app_type'] = 'previous'
print(df1.shape, df2.shape)
df = pd.concat([df1,df2])

if df1.shape[0] == df[df.app_type=="current"].shape[0]:
    del df1
    del df2
    df.to_csv(os.path.join(DATA_DIR, "merged_appointment_edgelist.csv"), index=False)
# Out:
# (1848, 7) (2627, 7)

# %%
### Get role data from html

# %%
def extract_html_links(text):
    """
    Grab any GOV.UK domain-specific (people) links from page text.
    :param text: Text within a details sub-section, refer to filtered for keys.
    :return: list of links
    """
    links = []
    try:
        soup = BeautifulSoup(text, "html.parser")
        links = [link.get('href') for link in soup.findAll('a', href=True)]
    except Exception as e:
        print("error")
        print(e)
    return [l.replace("https://www.gov.uk/", "/") for l in links if l.startswith("/")]

# %%
target = "https://www.gov.uk/government/ministers"
text = urllib.request.urlopen(target).read().decode('utf-8')
llist = extract_html_links(text)

# %%
Counter(["/".join(l.split("/")[0:3]) for l in llist if l.startswith("/government")] )
# Out:
# Counter({'/government/organisations': 27,
#          '/government/how-government-works': 2,
#          '/government/get-involved': 1,
#          '/government/statistics': 1,
#          '/government/people': 192,
#          '/government/ministers': 177})

# %%
soup = BeautifulSoup(text, "html.parser")
divs = soup.findAll("div", {"class": "ministers-by-organisation"})

# %%
divs[1]
# Out:
# <div class="ministers-by-organisation whips">
# <div class="inner-block floated-children">
# <h2 id="whips">Whips</h2>
# <section class="whitehall_whip_organisation" id="whitehall_whip_organisation_1">
# <div class="heading">
# <h3>House of Commons</h3>
# </div>
# <ul class="minister-list">
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_2277">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/julian-smith"><span class="person-title">The Rt Hon</span> <strong>Julian Smith MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/parliamentary-secretary-to-the-treasury-and-chief-whip">Parliamentary Secretary to the Treasury (Chief Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_2814">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/christopher-pincher"><strong>Christopher  Pincher  MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/deputy-chief-whip-comptroller-of-hm-household--2">Treasurer of HM Household (Deputy Chief Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_2812">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/mark-spencer"><strong>Mark Spencer MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/comptroller-of-hm-household-government-whip">Comptroller of HM Household (Government Whip) </a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_3133">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/craig-whittaker"><strong>Craig Whittaker MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip--2">Vice Chamberlain of HM Household (Government Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# </ul>
# </section> <hr class="keyline"/>
# <section class="whitehall_whip_organisation" id="whitehall_whip_organisation_3">
# <div class="heading">
# <h3>Junior Lords of the Treasury</h3>
# </div>
# <ul class="minister-list">
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_3129">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/mike-freer"><strong>Mike Freer MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-lord-commissioner-of-hm-treasury">Government Whip, Lord Commissioner of HM Treasury</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3819">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/alister-jack"><strong>Alister Jack MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-lord-commissioner-of-hm-treasury--3">Government Whip, Lord Commissioner of HM Treasury</a>
# <span>Unpaid</span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3128">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/rebecca-harris"><strong>Rebecca Harris MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-lord-commissioner-of-hm-treasury--4">Government Whip, Lord Commissioner of HM Treasury</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_3127">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/david-rutley"><strong>David Rutley MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-lord-commissioner-of-hm-treasury--8">Government Whip, Lord Commissioner of HM Treasury</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3605">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/jeremy-quin"><strong>Jeremy Quin MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-lord-commissioner-of-hm-treasury--5">Government Whip, Lord Commissioner of HM Treasury</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# </ul>
# </section> <hr class="keyline"/>
# <section class="whitehall_whip_organisation" id="whitehall_whip_organisation_4">
# <div class="heading">
# <h3>Assistant Whips</h3>
# </div>
# <ul class="minister-list">
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_3346">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/nusrat-ghani"><strong>Nusrat  Ghani MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--10">Assistant Government Whip</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3604">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/iain-stewart"><strong>Iain Stewart  MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--8">Assistant Government Whip</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3347">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/jo-churchill"><strong>Jo Churchill MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--11">Assistant Government Whip</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_3348">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/amanda-milling"><strong>Amanda Milling MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--12">Assistant Government Whip</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3603">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/michelle-donelan"><strong>Michelle Donelan MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--13">Assistant Government Whip</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3898">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/matt-warman"><strong>Matt Warman MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--17">Assistant Government Whip</a>
# <span>Unpaid</span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_3351">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/wendy-morton"><strong>Wendy Morton MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--7">Assistant Government Whip</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3872">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/kevin-foster"><strong>Kevin Foster MP</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/assistant-government-whip--16">Assistant Government Whip</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# </ul>
# </section> <hr class="keyline"/>
# <section class="whitehall_whip_organisation" id="whitehall_whip_organisation_2">
# <div class="heading">
# <h3>House of Lords</h3>
# </div>
# <ul class="minister-list">
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_255">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/lord-taylor-of-holbeach"><span class="person-title">The Rt Hon</span> <strong>Lord Taylor of Holbeach CBE</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/lords-chief-whip-and-captain-of-the-honourable-corps-of-gentlemen-at-arms">Lords Chief Whip and Captain of the Honourable Corps of Gentlemen at Arms</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_2284">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/earl-of-courtown"><strong>Earl of Courtown</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-deputy-chief-whip-and-captain-of-the-queens-bodyguard-of-the-yeomen-of-the-guard">Government Deputy Chief Whip and Captain of the Queen's Bodyguard of the Yeomen of the Guard</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# </ul>
# </section> <hr class="keyline"/>
# <section class="whitehall_whip_organisation" id="whitehall_whip_organisation_5">
# <div class="heading">
# <h3>Baronesses and Lords in Waiting</h3>
# </div>
# <ul class="minister-list">
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_2976">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/baroness-vere-of-norbiton"><strong>Baroness Vere of Norbiton</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/baroness-in-waiting-government-whip--3">Baroness in Waiting (Government Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3126">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/baroness-sugg"><strong>Baroness Sugg  CBE </strong></a></h4>
# <p class="role">
# <a href="/government/ministers/baroness-in-waiting-government-whip--5">Baroness in Waiting (Government Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_2817">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/baroness-goldie"><strong>Baroness Goldie DL</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-baroness-in-waiting--5">Baroness in Waiting (Government Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_3809">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/baroness-barran"><strong>Baroness  Barran MBE</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/baroness-in-waiting-government-whip--4">Baroness in Waiting (Government Whip)</a>
# <span>Unpaid</span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_3273">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/deborah-stedman-scott"><strong>Baroness Deborah Stedman-Scott OBE DL</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/baroness-in-waiting-government-whip--2">Baroness in Waiting (Government Whip)</a>
# <span>Unpaid</span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt" id="by-organisation_person_412">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/viscount-younger-of-leckie"><strong>Viscount Younger of Leckie</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-lord-in-waiting--7">Lord in Waiting (Government Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# <li class="by-organisation_person person-excerpt clear-person" id="by-organisation_person_2824">
# <div class="inner">
# <div class="text">
# <h4 class="current-appointee"><a href="/government/people/lord-young-of-cookham"><span class="person-title">The Rt Hon</span> <strong>Lord Young of Cookham CH</strong></a></h4>
# <p class="role">
# <a href="/government/ministers/government-whip-lord-in-waiting--8">Lord in Waiting (Government Whip)</a>
# <span></span> </p>
# </div>
# </div>
# </li>
# </ul>
# </section> <hr class="keyline"/>
# </div>
# </div>

# %%
row_list = []

for section in divs[0].findAll("section"):
    org = section.find("a", {"class": "organisation-logo"}).get('href')
    
    
    sections = section.findAll(["h4","p"])
#         {"class": "current-appointee"}
    for i,link in enumerate(sections):
        if i < len(sections)-1 and i%2==0:
            people = [l.get('href') for l in link.findAll('a', href=True)]
            if len(people)==1:
                row_dict = {'person':people[0],
                            'roles':[l.get('href') for l\
                                     in sections[i+1].findAll('a', href=True)],
                            'organisation':org
                           }
                row_list.append(row_dict)
            else:
                print("error")
df_roles = pd.DataFrame(row_list)
df_roles = df_roles[['person', 'roles', 'organisation']]

# %%
df_roles
# Out:
#                                              person  \
# 0                    /government/people/theresa-may
# 1                /government/people/david-lidington
# 2                  /government/people/brandon-lewis
# 3                         /government/people/dowden
# 4                    /government/people/chloe-smith
# 5                   /government/people/kevin-foster
# 6                 /government/people/philip-hammond
# 7                /government/people/elizabeth-truss
# 8                   /government/people/jesse-norman
# 9                 /government/people/robert-jenrick
# 10                     /government/people/john-glen
# 11                   /government/people/sajid-javid
# 12                /government/people/caroline-nokes
# 13                   /government/people/ben-wallace
# 14                     /government/people/nick-hurd
# 15    /government/people/susan-williams-of-trafford
# 16               /government/people/victoria-atkins
# 17                   /government/people/jeremy-hunt
# 18                   /government/people/alan-duncan
# 19               /government/people/andrew-murrison
# 20       /government/people/lord-ahmad-of-wimbledon
# 21                    /government/people/mark-field
# 22              /government/people/harriett-baldwin
# 23               /government/people/stephen-barclay
# 24                 /government/people/lord-callanan
# 25                  /government/people/robin-walker
# 26                /government/people/james-cleverly
# 27                /government/people/kwasi-kwarteng
# 28                /government/people/penny-mordaunt
# 29                     /government/people/lord-howe
# ..                                              ...
# 76                    /government/people/amber-rudd
# 77                   /government/people/alok-sharma
# 78              /government/people/justin-tomlinson
# 79                  /government/people/guy-opperman
# 80             /government/people/baroness-buscombe
# 81                   /government/people/will-quince
# 82                 /government/people/david-mundell
# 83                    /government/people/ian-duncan
# 84                /government/people/alun-cairns-mp
# 85    /government/people/lord-bourne-of-aberystwyth
# 86                  /government/people/kevin-foster
# 87                 /government/people/karen-bradley
# 88                  /government/people/john-penrose
